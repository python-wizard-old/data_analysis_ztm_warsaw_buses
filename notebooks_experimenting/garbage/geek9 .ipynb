# %%
# https://python.plainenglish.io/from-api-to-pandas-getting-json-data-with-python-df127f699b6b

# %%
# to handle  data retrieval
import urllib3
from urllib3 import request# to handle certificate verification
import certifi# to manage json data
import json# for pandas dataframes
import pandas as pd# uncomment below if installation needed (not necessary in Colab)
#!pip install certifi

# %%
from datetime import datetime

# %%
import time

# %%
# handle certificate verification and SSL warnings
# https://urllib3.readthedocs.io/en/latest/user-guide.html#ssl

http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED', ca_certs=certifi.where())

# %%
# get data from the API
url = 'https://api.um.warszawa.pl/api/action/busestrams_get/?resource_id=f2e5503e-927d-4ad3-9500-4ab9e55deb59&apikey=7a621357-5917-4df8-ae3d-8889bb779dd4&type=1'

# %%
def load_api_save_file(directory=''):
    r = http.request('GET', url)
    print(r.status)
    
    # decode json data into a dict object
    data = json.loads(r.data.decode('utf-8'))
    
    if(type(data['result']) == list):
       
    
        df = pd.json_normalize(data, 'result')
        df.head(10)

        # datetime object containing current date and time
        now = datetime.now()

        # dd/mm/YY H:M:S
        dt_string = now.strftime("%d-%m-%Y %H:%M:%S")
        print("date and time =", dt_string)	


        file_name = "ztm_bus_data_"
        file_name += dt_string
        file = directory + '/' + file_name

        df.to_csv(file)

# %%
for i in range(360):
    load_api_save_file('ztm_file_export_whole_hour')
    time.sleep(10)
# Out:
# 200
# date and time = 26-06-2021 17:23:57
# 200
# date and time = 26-06-2021 17:24:07
# 200
# date and time = 26-06-2021 17:24:18
# 200
# date and time = 26-06-2021 17:24:28
# 200
# date and time = 26-06-2021 17:24:38
# 200
# date and time = 26-06-2021 17:24:49
# 200
# date and time = 26-06-2021 17:25:00
# 200
# date and time = 26-06-2021 17:25:10
# 200
# date and time = 26-06-2021 17:25:21
# 200
# date and time = 26-06-2021 17:25:31
# 200
# date and time = 26-06-2021 17:25:42
# 200
# date and time = 26-06-2021 17:25:52
# 200
# date and time = 26-06-2021 17:26:03
# 200
# date and time = 26-06-2021 17:26:13
# 200
# date and time = 26-06-2021 17:26:24
# 200
# date and time = 26-06-2021 17:26:34
# 200
# date and time = 26-06-2021 17:26:45
# 200
# date and time = 26-06-2021 17:26:56
# 200
# date and time = 26-06-2021 17:27:06
# 200
# 200
# date and time = 26-06-2021 17:27:27
# 200
# date and time = 26-06-2021 17:27:37
# 200
# date and time = 26-06-2021 17:27:48
# 200
# date and time = 26-06-2021 17:27:58
# 200
# date and time = 26-06-2021 17:28:09
# 200
# date and time = 26-06-2021 17:28:19
# 200
# date and time = 26-06-2021 17:28:30
# 200
# date and time = 26-06-2021 17:28:40
# 200
# date and time = 26-06-2021 17:28:51
# 200
# date and time = 26-06-2021 17:29:01
# 200
# date and time = 26-06-2021 17:29:12
# 200
# date and time = 26-06-2021 17:29:22
# 200
# date and time = 26-06-2021 17:29:33
# 200
# date and time = 26-06-2021 17:29:43
# 200
# date and time = 26-06-2021 17:29:53
# 200
# date and time = 26-06-2021 17:30:04
# 200
# date and time = 26-06-2021 17:30:14
# 200
# date and time = 26-06-2021 17:30:25
# 200
# date and time = 26-06-2021 17:30:35
# 200
# date and time = 26-06-2021 17:30:45
# 200
# date and time = 26-06-2021 17:30:56
# 200
# date and time = 26-06-2021 17:31:06
# 200
# date and time = 26-06-2021 17:31:17
# 200
# 200
# date and time = 26-06-2021 18:10:08
# 200
# date and time = 26-06-2021 18:10:19
# 200
# date and time = 26-06-2021 18:10:29
# 200
# date and time = 26-06-2021 18:10:41
# 200
# date and time = 26-06-2021 18:10:53
# 200
# date and time = 26-06-2021 18:11:03
# 200
# date and time = 26-06-2021 18:11:14
# 200
# date and time = 26-06-2021 18:11:24
# 200
# date and time = 26-06-2021 18:11:35
# 200
# date and time = 26-06-2021 18:11:45
# 200
# date and time = 26-06-2021 18:11:56
# 200
# date and time = 26-06-2021 18:12:07
# 200
# date and time = 26-06-2021 18:12:18
# 200
# date and time = 26-06-2021 18:12:29
# 200
# date and time = 26-06-2021 18:12:39
# 200
# date and time = 26-06-2021 18:12:49
# 200
# date and time = 26-06-2021 18:13:00
# 200
# date and time = 26-06-2021 18:13:11
# 200
# date and time = 26-06-2021 18:13:21
# 200
# date and time = 26-06-2021 18:13:32
# 200
# date and time = 26-06-2021 18:13:42
# 200
# date and time = 26-06-2021 18:13:53
# 200
# date and time = 26-06-2021 18:14:03
# 200
# date and time = 26-06-2021 18:14:15
# 200
# date and time = 26-06-2021 18:14:26
# 200
# date and time = 26-06-2021 18:14:37
# 200
# date and time = 26-06-2021 18:14:48
# 200
# date and time = 26-06-2021 18:14:59
# 200
# date and time = 26-06-2021 18:15:09
# 200
# date and time = 26-06-2021 18:15:22
# 200
# date and time = 26-06-2021 18:15:33
# 200
# date and time = 26-06-2021 18:15:43
# 200
# date and time = 26-06-2021 18:15:54
# 200
# 200
# date and time = 26-06-2021 18:16:15
# 200
# date and time = 26-06-2021 18:16:26
# 200
# date and time = 26-06-2021 18:16:37
# 200
# date and time = 26-06-2021 18:16:47
# 200
# date and time = 26-06-2021 18:16:58
# 200
# date and time = 26-06-2021 18:17:09
# 200
# date and time = 26-06-2021 18:17:19
# 200
# date and time = 26-06-2021 18:17:30
# 200
# date and time = 26-06-2021 18:17:41
# 200
# date and time = 26-06-2021 18:17:51
# 200
# date and time = 26-06-2021 18:18:02
# 200
# date and time = 26-06-2021 18:18:13
# 200
# date and time = 26-06-2021 18:18:24
# 200
# date and time = 26-06-2021 18:18:34
# 200
# date and time = 26-06-2021 18:18:45
# 200
# date and time = 26-06-2021 18:18:55
# 200
# date and time = 26-06-2021 18:19:06
# 200
# date and time = 26-06-2021 18:19:17
# 200
# date and time = 26-06-2021 18:19:27
# 200
# date and time = 26-06-2021 18:19:38
# 200
# date and time = 26-06-2021 18:19:48
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-d238daf2006e> in <module>
#       1 for i in range(360):
# ----> 2     load_api_save_file('ztm_file_export_whole_hour')
#       3     time.sleep(10)
#
# <ipython-input-7-9960321ff686> in load_api_save_file(directory)
#      24         file = directory + '/' + file_name
#      25
# ---> 26         df.to_csv(file)
#      27
#      28
#
# ~/extra/miniconda/envs/nlp/lib/python3.9/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ~/extra/miniconda/envs/nlp/lib/python3.9/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~/extra/miniconda/envs/nlp/lib/python3.9/site-packages/pandas/io/formats/csvs.py in save(self)
#     226         """
#     227         # apply compression and byte/text conversion
# --> 228         with get_handle(
#     229             self.filepath_or_buffer,
#     230             self.mode,
#
# ~/extra/miniconda/envs/nlp/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ztm_file_export_whole_hour/ztm_bus_data_26-06-2021 18:19:48'

# %%
r = http.request('GET', url)
r.status
# Out:
# 200

# %%
# decode json data into a dict object
data = json.loads(r.data.decode('utf-8'))
data['result'][:5]
# Out:
# [{'Lines': '213',
#   'Lon': 21.1152613,
#   'VehicleNumber': '1000',
#   'Time': '2021-06-25 23:22:58',
#   'Lat': 52.2346205,
#   'Brigade': '3'},
#  {'Lines': '213',
#   'Lon': 21.115043,
#   'VehicleNumber': '1001',
#   'Time': '2021-06-25 23:56:49',
#   'Lat': 52.23463,
#   'Brigade': '1'},
#  {'Lines': '213',
#   'Lon': 21.2196693,
#   'VehicleNumber': '1003',
#   'Time': '2021-06-26 14:19:17',
#   'Lat': 52.1637016,
#   'Brigade': '1'},
#  {'Lines': '311',
#   'Lon': 21.115233,
#   'VehicleNumber': '1004',
#   'Time': '2021-06-25 21:52:40',
#   'Lat': 52.23458,
#   'Brigade': '2'},
#  {'Lines': '196',
#   'Lon': 21.11514,
#   'VehicleNumber': '1005',
#   'Time': '2021-06-25 23:48:58',
#   'Lat': 52.234611,
#   'Brigade': '1'}]

# %%
df = pd.json_normalize(data, 'result')
df.head(10)
# Out:
#   Lines        Lon VehicleNumber                 Time        Lat Brigade
# 0   213  21.115261          1000  2021-06-25 23:22:58  52.234620       3
# 1   213  21.115043          1001  2021-06-25 23:56:49  52.234630       1
# 2   213  21.219669          1003  2021-06-26 14:19:17  52.163702       1
# 3   311  21.115233          1004  2021-06-25 21:52:40  52.234580       2
# 4   196  21.115140          1005  2021-06-25 23:48:58  52.234611       1
# 5   130  21.115590          1008  2021-06-25 20:19:05  52.234613      04
# 6   213  21.089413          1010  2021-06-26 14:19:14  52.220626       2
# 7   213  21.223388          1011  2021-06-26 14:19:21  52.160044       4
# 8   311  21.115517          1012  2021-06-25 21:16:38  52.234615       1
# 9   213  21.089450          1015  2021-06-26 14:19:10  52.220059       3

# %%
df['Lines'] == '111'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 985    False
# 986    False
# 987    False
# 988    False
# 989    False
# Name: Lines, Length: 990, dtype: bool

# %%
df[df['Lines'] == '111']
# Out:
#     Lines        Lon VehicleNumber                 Time        Lat Brigade
# 436   111  21.062666          5900  2021-06-26 14:19:18  52.230801       4
# 445   111  21.101866          5920  2021-06-26 14:19:15  52.225124       6
# 447   111  21.107388          5922  2021-06-26 07:42:12  52.233645
# 448   111  21.116245          5926  2021-06-26 00:24:55  52.234005       5
# 449   111  21.009554          5927  2021-06-26 14:19:17  52.233833       3
# 450   111  21.006691          5931  2021-06-26 14:19:15  52.238033       8
# 482   111  21.102476          5984  2021-06-26 14:19:18  52.222061       5
# 483   111  21.057146          5985  2021-06-26 14:19:18  52.237259       7
# 484   111  20.982103          5986  2021-06-26 14:19:18  52.245338       2
# 495   111  20.979559          5999  2021-06-26 14:19:16  52.244495       1

# %%
print(df['Lines'] = 213)
# Out:
#   File "<ipython-input-29-5cd15f9ab011>", line 1
#     print(df['Lines'] = 213)
#           ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
from datetime import datetime

# %%
# datetime object containing current date and time
now = datetime.now()
 
print("now =", now)

# dd/mm/YY H:M:S
dt_string = now.strftime("%d-%m-%Y %H:%M:%S")
print("date and time =", dt_string)
# Out:
# now = 2021-06-26 14:33:50.498460
# date and time = 26-06-2021 14:33:50

# %%
# datetime object containing current date and time

# dd/mm/YY H:M:S
dt_string = now.strftime("%d-%m-%Y %H:%M:%S")
print("date and time =", dt_string)	

directory = 'ztm_file_export/'
file_name = "ztm_bus_data_"
file_name += dt_string

df.to_csv(directory+file_name)

# %%
https://api.um.warszawa.pl/api/action/busestrams_get/?resource_id=f2e5503e-927d-4ad3-9500-4ab9e55deb59&apikey=7a621357-5917-4df8-ae3d-8889bb779dd4&type=1

7a621357-5917-4df8-ae3d-8889bb779dd4
