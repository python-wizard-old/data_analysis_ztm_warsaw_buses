# %%
import pandas as pd
import geopandas as gpd

# %%
import spacial_data_analysis_ztm

# %%
df = spacial_data_analysis_ztm.load_files_directory_into_df('data/28.06.2021_night_minute')
# Out:
# data/28.06.2021_night_minute
# FInished importing files

# %%
gdf = spacial_data_analysis_ztm.covert_long_lat_into_geodataframe(df)

# %%
gdf
# Out:
#       Lines        Lon VehicleNumber                Time        Lat Brigade  \
# 0       213  21.115615          1000 2021-06-27 23:51:33  52.234600       2
# 1       213  21.115168          1001 2021-06-28 00:30:59  52.234600       3
# 2       213  21.114898          1003 2021-06-27 00:02:20  52.234726       1
# 3       213  21.115269          1005 2021-06-27 23:19:40  52.234594       4
# 4       130  21.115590          1008 2021-06-25 20:19:05  52.234613      04
# ...     ...        ...           ...                 ...        ...     ...
# 32561   N42  21.005203          9908 2021-06-28 01:51:33  52.239380       1
# 32562   N43  20.980776          9915 2021-06-28 01:51:29  52.216171       2
# 32563   N42  20.899668          9926 2021-06-28 01:51:33  52.238693     218
# 32564   N42  20.947990          9928 2021-06-28 01:51:33  52.238625     216
# 32565   N43  20.976252          9929 2021-06-28 01:51:31  52.211041       3
#
#        Unnamed: 0                   geometry
# 0             0.0  POINT (21.11562 52.23460)
# 1             1.0  POINT (21.11517 52.23460)
# 2             2.0  POINT (21.11490 52.23473)
# 3             3.0  POINT (21.11527 52.23459)
# 4             4.0  POINT (21.11559 52.23461)
# ...           ...                        ...
# 32561       434.0  POINT (21.00520 52.23938)
# 32562       435.0  POINT (20.98078 52.21617)
# 32563       436.0  POINT (20.89967 52.23869)
# 32564       437.0  POINT (20.94799 52.23862)
# 32565       438.0  POINT (20.97625 52.21104)
#
# [16243 rows x 8 columns]

# %%
gdf = gdf.to_crs(epsg=2178)

# %%
gdf.crs
# Out:
# <Projected CRS: EPSG:2178>
# Name: ETRS89 / Poland CS2000 zone 7
# Axis Info [cartesian]:
# - x[north]: Northing (metre)
# - y[east]: Easting (metre)
# Area of Use:
# - name: Poland - onshore and offshore between 19°30'E and 22°30'E.
# - bounds: (19.5, 49.09, 22.5, 54.55)
# Coordinate Operation:
# - name: Poland CS2000 zone 7
# - method: Transverse Mercator
# Datum: European Terrestrial Reference System 1989 ensemble
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
# gdf["VehicleNumber"].iloc[0:10]

# %%
# lines = gdf["VehicleNumber"].iloc[0:10]

# %%
gdf = spacial_data_analysis_ztm.sort_vehicle_number_time(gdf)

# %%
gdf = spacial_data_analysis_ztm.remove_duplicates(gdf)

# %%
gdf = spacial_data_analysis_ztm.remove_vehicles_one_occurence(gdf)

# %%
gdf = spacial_data_analysis_ztm.calculate_distance_timedelta(gdf)
# Out:
# 9216, 8193, 1030, 1543, 1548, 9241, 9252, 1065, 1068, 7213, 1079, 6203, 6207, 7231, 7235, 7239, 7243, 6221, 9806, 9808, 9305, 7259, 5214, 9824, 6243, 8803, 5224, 4201, 5225, 8809, 4204, 4205, 9323, 4207, 9839, 5236, 8826, 8318, 4224, 9344, 9345, 9346, 4228, 8837, 8326, 4231, 4232, 8329, 4234, 9350, 8334, 4242, 7315, 8340, 2202, 8363, 8366, 8368, 1202, 9908, 8891, 1212, 1213, 9915, 1219, 1220, 8899, 9926, 1223, 9928, 9929, 2253, 9429, 9436, 9437, 8414, 9439, 9443,
# 326         326.0  POINT (7490772.809 5802962.913)         NaN
# 829         326.0  POINT (7490770.395 5802961.683)    2.709341
# 1332        326.0  POINT (7490773.091 5802964.738)    4.074632
# 1833        325.0  POINT (7490770.755 5802961.270)    4.180773
# 2335        325.0  POINT (7490772.260 5802961.134)    1.511374
# ...           ...                              ...         ...
# 30809       438.0  POINT (7497252.677 5787327.524)  743.066151
# 31247       436.0  POINT (7497412.497 5786898.742)  457.598586
# 31686       437.0  POINT (7497731.933 5786760.286)  348.151915
# 32125       437.0  POINT (7498174.300 5786508.427)  509.039878
# 32565       438.0  POINT (7498376.840 5786380.626)  239.490037
#
#             TimeDelta  seconds  speed_m/s  speed_km/h
# 326               NaT      NaN        NaN         NaN
# 829   0 days 00:00:57     57.0   0.047532    0.171116
# 1332  0 days 00:00:55     55.0   0.074084    0.266703
# 1833  0 days 00:01:04     64.0   0.065325    0.235168
# 2335  0 days 00:00:58     58.0   0.026058    0.093809
# ...               ...      ...        ...         ...
# 30809 0 days 00:01:06     66.0  11.258578   40.530881
# 31247 0 days 00:00:55     55.0   8.319974   29.951907
# 31686 0 days 00:00:52     52.0   6.695229   24.102825
# 32125 0 days 00:00:55     55.0   9.255271   33.318974
# 32565 0 days 00:01:09     69.0   3.470870   12.495132
#
# [8193 rows x 13 columns]

# %%
gdf['speed_km/h'].max()
# Out:
# 81.39289804045526

# %%
gdf[829].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/extra/miniconda/envs/nlp/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 829
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-f3cac346656d> in <module>
# ----> 1 gdf[829].plot()
#
# ~/extra/miniconda/envs/nlp/lib/python3.9/site-packages/geopandas/geodataframe.py in __getitem__(self, key)
#    1297         GeoDataFrame.
#    1298         """
# -> 1299         result = super(GeoDataFrame, self).__getitem__(key)
#    1300         geo_col = self._geometry_column_name
#    1301         if isinstance(result, Series) and isinstance(result.dtype, GeometryDtype):
#
# ~/extra/miniconda/envs/nlp/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/extra/miniconda/envs/nlp/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 829

# %%
warsaw_file = "https://raw.githubusercontent.com/andilabs/warszawa-dzielnice-geojson/master/warszawa-dzielnice.geojson"

# %%
warsaw = gpd.read_file(warsaw_file)

# %%
warsaw = warsaw.iloc[1:]

# %%
warsaw = warsaw.to_crs(epsg=2178)

# %%
for i in warsaw.index:
    pip = gdf.within(warsaw.loc[i, 'geometry'])
    gdf.loc[pip, 'Districs'] = warsaw.loc[i, 'name']

# %%
type(gdf)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
import matplotlib.pyplot as plt

# %%
bus
# Out:
# Lines                                                    150
# Lon                                                20.864511
# VehicleNumber                                            776
# Time                                     2021-06-28 00:45:18
# Lat                                                 52.35999
# Brigade
# Unnamed: 0                                             326.0
# geometry         POINT (7490770.394944785 5802961.682814109)
# distance                                            2.709341
# TimeDelta                                    0 days 00:00:57
# seconds                                                 57.0
# speed_m/s                                           0.047532
# speed_km/h                                          0.171116
# Districs                                                 NaN
# Name: 829, dtype: object

# %%
gdf.loc[9779,].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-b521d4b944f2> in <module>
# ----> 1 gdf.loc[9779,].plot()
#
# ~/extra/miniconda/envs/nlp/lib/python3.9/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~/extra/miniconda/envs/nlp/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/extra/miniconda/envs/nlp/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     276     def generate(self):
#     277         self._args_adjust()
# --> 278         self._compute_plot_data()
#     279         self._setup_subplots()
#     280         self._make_plot()
#
# ~/extra/miniconda/envs/nlp/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     439         # no non-numeric frames or series allowed
#     440         if is_empty:
# --> 441             raise TypeError("no numeric data to plot")
#     442
#     443         self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
bus = gdf.iloc[[829]]

# %%
bus
# Out:
#       Lines        Lon VehicleNumber                Time        Lat Brigade  \
# 28660   N03  21.092627          1527 2021-06-28 01:43:31  52.225298       5
#
#        Unnamed: 0                         geometry    distance  \
# 28660        58.0  POINT (7506328.945 5787970.713)  252.173431
#
#             TimeDelta  seconds  speed_m/s  speed_km/h        Districs
# 28660 0 days 00:01:03     63.0   4.002753    14.40991  Praga Południe

# %%
fig, ax = plt.subplots()
warsaw.plot(ax=ax)
bus.plot(ax=ax, color='red')
# Out:
# <AxesSubplot:>

# %%
pip = gdf.within(warsaw.loc[1, 'geometry'])

# %%
gdf.loc[pip, 'dupa'] = 'dupa'

# %%
gdf

# %%
pip

# %%
pip = gdf.within(pr_regions.loc[0, 'geometry'])

# %%
pip = gdf.within(pr_regions.loc[0, 'geometry'])

#creating a new gdf keep only the intersecting records
so_pr = gdf.loc[pip].copy()

#assign region name 
so_pr['region'] = pr_regions.Name[0]

so_pr.head()

# %%
set_vehicle_number = set(df["VehicleNumber"])
to_check_list = []
#
#                         .iloc[0:10]

# %%
# set_vehicle_number

# %%
for n in set_vehicle_number:
    if len(df[df["VehicleNumber"]==n]) > 5:
        to_check_list.append(n)
#         set_vehicle_number = set(df["VehicleNumber"])
#         to_check_list = []

# %%
to_check_list

# %%
lines

# %%
gdf_ = gpd.GeoDataFrame()

# %%
gdf_ = gpd.GeoDataFrame()
for bus_num in lines:
    print(bus_num)
    vehicle = gdf[gdf['VehicleNumber'] == bus_num]
    vehicle['distance'] = vehicle.distance(vehicle.shift())
#     y = s - s.shift()
    vehicle['TimeDelta'] = vehicle['Time'] - vehicle['Time'].shift()
    # here calculate timedeltas
    gdf_ = pd.concat([gdf_, vehicle])

return gdf_

# %%
len(gdf_.drop_duplicates())

# %%
gdf1.distance(gdf1.shift())

# %%
for bus_num in gdf["VehicleNumber"]:
    print(bus_num)

# %%
df[df['VehicleNumber'] == list_more7[0]]

# %%
list_more7 = []
for i in range(1000, 9955):
    if len(df[df['VehicleNumber'] == i]) > 7:
        list_more7.append(i)

# %%
list_more7[0]

# %%
df

# %%
import geopandas as gpd
from shapely.geometry import Point


geom=[Point(xy) for xy in zip([117.454361,117.459880],[38.8459879,38.846255])]
gdf=gpd.GeoDataFrame(geometry=geom,crs={'init':'epsg:4326'})
dis=gdf.distance(gdf.shift())
print(dis)

# %%
df[df['VehicleNumber'] == list_more7[0]].iloc[1]['Time']

# %%
df[df['VehicleNumber'] == list_more7[0]].iloc[2]['Time']

# %%
import geopandas

# %%
# Importing the great_circle module from the library
from geopy.distance import great_circle
  
# Loading the lat-long data for Kolkata & Delhi
kolkata = (22.5726, 88.3639)
delhi = (28.7041, 77.1025)
  
# Print the distance calculated in km
print(great_circle(kolkata, delhi).km)

# %%
pl1 = (52.17152, 21.226742)

# %%
pl2 = (52.171343, 21.226571)

# %%
great_circle(pl1, pl2).m

# %%
df['Time'] = pd.to_datetime(df['Time'])

# %%
df

# %%
df[df['VehicleNumber'] == list_more7[0]].iloc[1]['Time']

# %%
delta = df[df['VehicleNumber'] == list_more7[0]].iloc[2]['Time'] - df[df['VehicleNumber'] == list_more7[0]].iloc[1]['Time']

# %%
delta.seconds

# %%
22.8769267442839/12

# %%
1.9064105620236582 * (3600/1000)
